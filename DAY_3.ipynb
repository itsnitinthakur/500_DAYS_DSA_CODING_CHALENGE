# %% [markdown]
# # Search in Rotated Sorted Array
#
# There is an integer array nums sorted in ascending order (with distinct values).
#
# Prior to being passed to your function, nums is rotated at an unknown pivot index k (0 <= k < nums.length) such that the resulting array is [nums[k], nums[k+1], ..., nums[n-1], nums[0], nums[1], ..., nums[k-1]] (0-indexed). For example, [0,1,2,4,5,6,7] might be rotated at pivot index 3 and become [4,5,6,7,0,1,2].
#
# Given the array nums after the rotation and an integer target, return the index of target if it is in nums, or -1 if it is not in nums.
#
#
#
# Example 1:
#
# Input: nums = [4,5,6,7,0,1,2], target = 0
# Output: 4
# Example 2:
#
# Input: nums = [4,5,6,7,0,1,2], target = 3
# Output: -1
# Example 3:
#
# Input: nums = [1], target = 0
# Output: -1
#
#
# Constraints:
#
# 1 <= nums.length <= 5000
# -104 <= nums[i] <= 104
# All values of nums are unique.
# nums is guaranteed to be rotated at some pivot.
# -104 <= target <= 104
#
#
# Follow up: Can you achieve this in O(log n) time complexity?

# %%
class Solution:
def search(self, nums: List[int], target: int) -> int:
if target in nums:
return nums.index(target)
elif target not in nums:
return -1

# %% [markdown]
# # Find First and Last Position of Element in Sorted Array
#
# Given an array of integers nums sorted in ascending order, find the starting and ending position of a given target value.
#
# If target is not found in the array, return [-1, -1].
#
# Follow up: Could you write an algorithm with O(log n) runtime complexity?
#
#
#
# Example 1:
#
# Input: nums = [5,7,7,8,8,10], target = 8
# Output: [3,4]
# Example 2:
#
# Input: nums = [5,7,7,8,8,10], target = 6
# Output: [-1,-1]
# Example 3:
#
# Input: nums = [], target = 0
# Output: [-1,-1]
#
#
# Constraints:
#
# 0 <= nums.length <= 105
# -109 <= nums[i] <= 109
# nums is a non-decreasing array.
# -109 <= target <= 109

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        f=[]
        c=0
        if target not in nums and len(nums)<1:
            return [-1,-1]
        elif target in nums:
            c =nums.count(target)
            while c!=0:
                i = nums.index(target)
                f.append(i)
                c-=1
                i+=1
            return f

# %%
class Solution(object):
    def searchRange(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        l = []
        for i in range(len(nums)):
            if nums[i] == target:
                l.append(i)
        if l:
            return [l[0], l[-1]]
        else:
            return [-1, -1]

# %%
def searchRange(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        if not nums:
            return [-1,-1]
        
        if target not in nums:
            return [-1,-1]
        
        a = []
        n = len(nums) -1
        for i in nums:
            if i == target:
                a.append(nums.index(i))
                break
                
        nums.sort(reverse = True)
        for i in nums:
            if i == target:
                a.append(n-(nums.index(i)))
                break
                
        return a

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        
        if target not in nums:
            return [-1, -1]
        
        idxs = []        
        for idx, num in enumerate(nums):
            if num == target:
                idxs.append(idx)
            elif len(idxs) > 1:
                break
                
        return [min(idxs), max(idxs)]

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        
        # initliazation with -1 
        
        first=-1
        last =-1
        result =[]
        
        for n in range(len(nums)):
            
            # last matching position will be stored here.
            if nums[n] == target and first !=-1 :
                last =n
            
            # This condition will be sataesfied only for first time.
            if nums[n]== target and first ==-1:
                first = n
        
        # This is when there will be only one matching target element 
        if first != -1 and last ==-1:
            last =first
        
        
        result.append(first)
        result.append(last)
        
        return  result

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        if target in nums:
            start_point = nums.index(target)
            end_point = start_point + nums.count(target) - 1
            return [start_point, end_point]
        else:
            return [-1, -1]

# %% [markdown]
# # Minimum Changes To Make Alternating Binary String
#
# You are given a string s consisting only of the characters '0' and '1'. In one operation, you can change any '0' to '1' or vice versa.
#
# The string is called alternating if no two adjacent characters are equal. For example, the string "010" is alternating, while the string "0100" is not.
#
# Return the minimum number of operations needed to make s alternating.
#
#
#
# Example 1:
#
# Input: s = "0100"
# Output: 1
# Explanation: If you change the last character to '1', s will be "0101", which is alternating.
# Example 2:
#
# Input: s = "10"
# Output: 0
# Explanation: s is already alternating.
# Example 3:
#
# Input: s = "1111"
# Output: 2
# Explanation: You need two operations to reach "0101" or "1010".
#
#
# Constraints:
#
# 1 <= s.length <= 104
# s[i] is either '0' or '1'.

# %%
class Solution:
    def minOperations(self, s: str) -> int:
        l = len(s)
        h = l//2
        c = s.count('1')
        if c==h:
            return 0
        elif c>h:
            return c-h
        elif c<h:
            return h-c

# %%
class Solution:
    def minOperations(self, s: str) -> int:
        possible = [
            '01'*(len(s)//2) + ('0' if len(s) % 2 else ''),
            '10'*(len(s)//2) + ('1' if len(s) % 2 else '')
        ]
        return min(
            sum(1 if c1 != c2 else 0 for c1, c2 in zip(s, p))
            for p in possible
        )

# %%
def minOperations(self, s):
        change = 0
        even_1 = 0
        even_0 = 0
        odd_1 = 0
        odd_0 = 0
        for i in range(len(s)):
            if(i%2 == 0):
                #even number
                if(s[i]=='1'):
                    even_1 +=1
                else:
                    even_0 +=1
            else:
                if(s[i] == '1'):
                    odd_1 +=1
                else:
                    odd_0 +=1
        if((even_1+odd_0)>(even_0+odd_1)):
           change = even_0 + odd_1
        else:
           change = even_1 + odd_0
        return change

# %%
def minOperations(self, s: str) -> int:
	i = 0
    zerosInOdd, onesInEven = 0, 0
    zerosInEven, onesInOdd = 0, 0
    
	for i in range(len(s)):
        if i % 2 == 0:
            if int(s[i]) == 0:
                zerosInEven += 1
            else:
                onesInEven += 1
        else:
            if int(s[i]) == 1:
                onesInOdd += 1
            else:
                zerosInOdd += 1
    scenarioOne = zerosInOdd + onesInEven
    scenarioTwo = zerosInEven + onesInOdd
    
    return min(len(s) - scenarioOne, len(s) - scenarioTwo)

# %%
evenChanges = 0
    oddChanges = 0
    evenString = []
    oddString = []
    
    for x in s:
        evenString.append(x)
        oddString.append(x)
        
    ##Changes the string for the even List
    for x in range(len(evenString)):
        if x == 0 and evenString[x] != "0":
            evenString[x] = "0"
            evenChanges += 1
        if x != len(evenString)-1:
            if evenString[x] == evenString[x+1] and evenString[x] == "0":
                evenChanges += 1
                evenString[x+1] = "1"
            if evenString[x] == evenString[x+1] and evenString[x] == "1":
                evenString[x+1] = "0"
                evenChanges += 1
    
    ##Changes the string for the odd List
    for x in range(len(oddString)):
        if x == 0 and oddString[x] != "1":
            oddString[x] = "1"
            oddChanges += 1
        if x != len(oddString)-1:
            if oddString[x] == oddString[x+1] and oddString[x] == "0":
                oddChanges += 1
                oddString[x+1] = "1"
            if oddString[x] == oddString[x+1] and oddString[x] == "1":
                oddString[x+1] = "0"
                oddChanges += 1
    
    return min(oddChanges, evenChanges)

# %%
int minOperations(string s) {
        int c1=0;
        int c2=0;
        vector<char> s1(s.size(),'0');// always remember this to initialize character arr
        vector<char> s2(s.size(),'1');// enclosed always in single 
        for(int i=0;i<s.size();i++)
        {
            if((i%2)!=0)
            {
                s1[i]='1';
                s2[i]='0';
            }
        }
        for(int i=0;i<s.size();i++)
        {
            if(s1[i]!=s[i])
                c1++;
            else if(s2[i]!=s[i])
                c2++;
        }
        return min(c1,c2);
    }

# %%
impl Solution {
    pub fn min_operations(s: String) -> i32 {
        let s01 = ['0', '1'];
        let mut i = 0;
        let (mut oper0, mut oper1) = (0, 0);

        s.chars().for_each(|c| {
            match c != s01[i] {
                true => oper0 += 1,
                false => oper1 += 1,
            }
            i = (i + 1) % 2;
        });

        oper0.min(oper1)
    }
}
