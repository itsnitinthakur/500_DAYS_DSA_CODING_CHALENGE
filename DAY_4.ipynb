# %% [markdown]
# # Combination Sum (dyanmic programming)
#
# Given an array of distinct integers candidates and a target integer target, return a list of all unique combinations of candidates where the chosen numbers sum to target. You may return the combinations in any order.
#
# The same number may be chosen from candidates an unlimited number of times. Two combinations are unique if the frequency of at least one of the chosen numbers is different.
#
# It is guaranteed that the number of unique combinations that sum up to target is less than 150 combinations for the given input.
#
#
#
# Example 1:
#
# Input: candidates = [2,3,6,7], target = 7
# Output: [[2,2,3],[7]]
# Explanation:
# 2 and 3 are candidates, and 2 + 2 + 3 = 7. Note that 2 can be used multiple times.
# 7 is a candidate, and 7 = 7.
# These are the only two combinations.
# Example 2:
#
# Input: candidates = [2,3,5], target = 8
# Output: [[2,2,2,2],[2,3,3],[3,5]]
# Example 3:
#
# Input: candidates = [2], target = 1
# Output: []
# Example 4:
#
# Input: candidates = [1], target = 1
# Output: [[1]]
# Example 5:
#
# Input: candidates = [1], target = 2
# Output: [[1,1]]
#
#
# Constraints:
#
# 1 <= candidates.length <= 30
# 1 <= candidates[i] <= 200
# All elements of candidates are distinct.
# 1 <= target <= 500

# %%
# not a complete solution 
class Solution:
    def combinationSum(self, candidates,target):
                       
        l=[[l1][l2][l3][l4]]
        for i in range (1, len(candidates)):
            if target % candidates[i-1]==0:
                z = target/candidates[i-1]
                while int(z)!=0:
                    l1.append(i-1)
                    z-=1
                l.append(l1)
            elif (target%candidates[i-1]) in candidates:
                z = target//candidates[i-1]
                while z!=0:
                    l2.append(i-1)
                    z-=1
                l.append(l2)
            elif (candidates[i]+candidates[i-1])==target:
                l3.append(i-1)
                l3.append(i)
                l.append(l3)
            elif target in candidates:
                l4.append(target)
                l.append(l4)
        print(l)

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        result = []
        candidates.sort()
        def backtrack(remain, comb, start):
            if remain == 0:
                result.append(list(comb))
                return
            for i in range(start, len(candidates)):
                if remain - candidates[i] < 0:# optimization, skip the rest elements becuase they are larger than candidates[i]  (candidates is sorted)
                    break
                backtrack(remain - candidates[i], comb + [ candidates[i] ], i) # [] convert candidates[i] to a list
        backtrack(target, [], 0)
        return result

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        if not candidates: return []
        
        dp = {}
        dp[0] = [[]]
        for candidate in sorted(candidates):
            for n in range(candidate, target + 1):
                combinations = dp.get(n - candidate, [])
                dp.setdefault(n, [])
                for combo in combinations:
                    dp[n].append(combo + [candidate])
        return dp.get(target, [])

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        candidates.sort()
        result = []
        def _dfs(candidates, target, index, current, result):
            for i in range(index, len(candidates)):
                c = candidates[i]
                if target == c:
                    result.append(current + [c])
                elif target > c:
                    _dfs(candidates, target - c, i, current + [c], result)
        _dfs(candidates, target, 0, [], result)
        return result

# %%
class Solution(object):
    def combinationSum(self, candidates, target):
        self.candidates = candidates
        self.result = []
        self.backT([],target,0)
        return self.result
    
    def backT(self,count,target,index):
        if target == 0:
            self.result.append(count)
            return
        if target < 0:
            return
        for i in range(index,len(self.candidates)):
            self.backT(count+[self.candidates[i]],target-self.candidates[i],i)
        return

# %%
class Solution(object):
    def combinationSum(self, candidates, target):
        """
        :type candidates: List[int]
        :type target: int
        :rtype: List[List[int]]
        """
        candidates.sort()
        dp = [[] for _ in range(target+1)]
        dp[0].append(0)
        for c in candidates:
            for t in range(c, target+1):
                if dp[t-c]: dp[t].append(c)
                
        ans = []
        def backtrack(t, m, prefix):
            if not t: 
                return ans.append(prefix[:])
            for c in dp[t]:
                if c > m: break
                prefix.append(c)
                backtrack(t-c, c, prefix)
                prefix.pop()
        backtrack(target, target, [])
        return ans

# %%
class Solution:
    def helper(self, index, candidates, soln, target, res): 
        if target == 0: 
            res.append(soln)
            return
        if target < 0 or index == len(candidates): 
            return
        self.helper(index+1, candidates, soln, target, res)
        self.helper(index, candidates, [candidates[index]]+soln, target-candidates[index], res)
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        res = []
        self.helper(0, candidates, [], target, res)
        return res

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        def backtrack(target, path, start):
            if target == 0: res.append(path)
            else:
                for i in range(start, len(candidates)):
                    if target - candidates[i] >= 0:
                        backtrack(target - candidates[i], path + [candidates[i]], i)
        
        res = []
        backtrack(target, [], 0)
        return res

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        ret = []
        
        def combinationSumHelper(currentCandidates=candidates, currentTarget=target, currentList=[]):
            if currentTarget <= 0:
                if currentTarget == 0:
                    ret.append(currentList)
                    
                return

            for idx, c in enumerate(currentCandidates):
                combinationSumHelper(currentCandidates[idx:], currentTarget - c, currentList + [c])
                
        combinationSumHelper()
        return ret;

# %% [markdown]
# # First Missing Positive
#
# Given an unsorted integer array nums, find the smallest missing positive integer.
#
#
#
# Example 1:
#
# Input: nums = [1,2,0]
# Output: 3
# Example 2:
#
# Input: nums = [3,4,-1,1]
# Output: 2
# Example 3:
#
# Input: nums = [7,8,9,11,12]
# Output: 1
#
#
# Constraints:
#
# 1 <= nums.length <= 300
# -231 <= nums[i] <= 231 - 1
#
#
# Follow up: Could you implement an algorithm that runs in O(n) time and uses constant extra space?
#
# Accepted
# 473.8K
# Submissions
# 1.4M

# %%
        s = nums.sort()
        for i in range(0,len(nums)):
            if i not in s:
                return len(s)+1
            elif i in s:
                if s[i]!=(s[i+!]-1):
                    return s[i+1]-1
            elif nums[i]==nums[i+1]:
                return 1

# %%
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        pos=1
        while pos in nums:
            pos+=1
        return(pos)
		```

# %%
 def firstMissingPositive(self, n: List[int]) -> int:
        if n == [0]:
            return 1
        n=set(n)
        s=[]
        s = [i for i in n if i>0 ] 
        if not s:
            return 1
        if min(s)!=1:
            return 1
        s.sort()
        p=s[0]
        for i in range(0,len(s)):
            if p!=s[i]:
                return p
            p=p+1
        return s[-1]+1

# %%
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        s = set(nums)
        for i in range(1, len(nums) + 10):
            if i not in s: return i

# %%
def firstMissingPositive(self, nums: List[int]) -> int:
    if max(nums) <=0:
        return 1
    s = set(nums)
    for i in range(min(1,max(nums)),max(nums)+2):
        if i not in s:
            return i

# %%
ef firstMissingPositive(self, nums: List[int]) -> int:
	 for i in range(1,2**32):
		if i not in nums:
                return i

# %% [markdown]
# # Next Permutation
#
# Implement next permutation, which rearranges numbers into the lexicographically next greater permutation of numbers.
#
# If such an arrangement is not possible, it must rearrange it as the lowest possible order (i.e., sorted in ascending order).
#
# The replacement must be in place and use only constant extra memory.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3]
# Output: [1,3,2]
# Example 2:
#
# Input: nums = [3,2,1]
# Output: [1,2,3]
# Example 3:
#
# Input: nums = [1,1,5]
# Output: [1,5,1]
# Example 4:
#
# Input: nums = [1]
# Output: [1]
#
#
# Constraints:
#
# 1 <= nums.length <= 100
# 0 <= nums[i] <= 100
# Accepted

# %%
class Solution:
    def nextPermutation(self, nums: List[int]) -> None:
        nums2=nums.copy()
        nums2.sort()
        if(nums==nums2[::-1]):
            nums.sort()
        else:
            l=len(nums)
            nums1=nums.copy()
            flag=0
            mini=-1
            arr=[]
            count=0
            for i in range(l-1,-1,-1):
                if(i<=l-2):
                    arr.append(nums[i+1])
                    count+=1
                if(i-1>=0):
                    j=i-1
                    if(nums1[i]>nums1[j]):
                        arr.sort()
                        for k in range(0,count):
                            if(arr[k]>nums[i-1]):
                                value=arr[k]
                                ind=(l-1)-k
                                flag=1
                                break
                        if(arr and flag==1):
                            mini=nums[ind]
                            if(mini>nums[i-1]):
                                nums[ind],nums[j]=nums[j],nums[ind]
                                self.sort(j,l,nums)
                            else:
                                nums[i],nums[j]=nums[j],nums[i]
                                self.sort(j,l,nums)
                        else:
                            nums[i],nums[j]=nums[j],nums[i]
                            self.sort(j,l,nums)
                        flag=1
                        break
                if(flag==1):
                    break
    def sort(self,j,l,nums):
        for k in range(j+1,l):
            for m in range(k+1,l):
                if(nums[m]<nums[k]):
                    nums[m],nums[k]=nums[k],nums[m]
        return nums

# %%
class Solution:
    def nextPermutation(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        # from last element find the end of descending seq
        l = len(nums)
        i = l-1
        min_n = -float('inf')
        while i>=0:
            if nums[i] >= min_n:
                min_n = nums[i]
                i -= 1
            else:
                break
        # binary search find the number greater than nums[i]
        #print(i)
        if i >= 0:
            x = nums[i]
            low,high = l-1,i+1
            def binarysearch(high,low,x):
                if high == low: return high
                if high - low == -1:
                    if nums[low] <= x:
                        return high
                    else:
                        return low
                else:
                    mid = (high+low)//2
                    if nums[mid] > x:
                        return binarysearch(mid,low,x)
                    else:
                        return binarysearch(high,mid,x)
            j = binarysearch(high,low,x)
            #print(j)
            nums[j],nums[i] = nums[i],nums[j]
            nums[i+1:] = nums[l-1:i:-1]
        else:
            nums[:] = nums[::-1]

# %%
        n = len(nums)
        i = n - 2
        # find X := the first descrease element from the end
        while i >= 0 and nums[i+1] <= nums[i]:
            i -= 1

        if i >= 0:
            j = n - 1 
            # find Y := the element just great than X
            while j >= 0 and nums[j] <= nums[i]:
                j -= 1
            # Swap X, Y
            nums[i], nums[j] = nums[j], nums[i]
        
        # reserve the tail
        nums[i+1:] = nums[i+1:][::-1]

# %%
class Solution:
    def nextPermutation(self, a: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        n = len(a)
        
        # find first decreasing from the end, a[i-1] is the one we need to move
        i = n - 1
        while i > 0 and a[i-1] >= a[i]:
            i -= 1
        
        # special case: a is the largest permutation
        if i == 0:
            pass
        else:
            # find the smallest number that larger than a[i-1] in i~n-1
            
            # solution 1: traverse
            # j = i
            # while j < n and a[i-1] < a[j]:
            #     j += 1
            # j -= 1
            
            # solution 2: binary search
            l = i
            r = n - 1
            while l < r:
                mid = (l+r+1)>>1
                if a[mid] > a[i-1]:
                    l = mid
                else:
                    r = mid - 1
            j = l

            # swap a[i-1] and a[j]
            t = a[i-1]            
            a[i-1] = a[j]
            a[j] = t
        
        # sort i~n-1, (reverse i~n-1)
        j = n-1
        while i < j:
            t = a[i]
            a[i] = a[j]
            a[j] = t
            i += 1
            j -= 1

# %% [markdown]
# # Find the Highest Altitude
#
# There is a biker going on a road trip. The road trip consists of n + 1 points at different altitudes. The biker starts his trip on point 0 with altitude equal 0.
#
# You are given an integer array gain of length n where gain[i] is the net gain in altitude between points i​​​​​​ and i + 1 for all (0 <= i < n). Return the highest altitude of a point.
#
#
#
# Example 1:
#
# Input: gain = [-5,1,5,0,-7]
# Output: 1
# Explanation: The altitudes are [0,-5,-4,1,1,-6]. The highest is 1.
# Example 2:
#
# Input: gain = [-4,-3,-2,-1,4,3,2]
# Output: 0
# Explanation: The altitudes are [0,-4,-7,-9,-10,-6,-3,-1]. The highest is 0.
#
#
# Constraints:
#
# n == gain.length
# 1 <= n <= 100
# -100 <= gain[i] <= 100

# %%
inf = float('-inf')
class Solution:
    def largestAltitude(self, gain: List[int]) -> int:
        best = inf
        c = 0
        for x in gain:
            if x>0:
                c += x
                best = max(c,best)
                c = max(c,0)
        return best

# %%
class Solution:
    def largestAltitude(self, gain: List[int]) -> int:
        lst = [0]
        for i in range(len(gain)):
            lst.append(gain[i]+lst[i])
        return max(lst)

# %%
class Solution:
    def largestAltitude(self, gain: List[int]) -> int:
        curr = 0
        best = 0
        for el in gain:
            curr += el
            best = max(best, curr)
        return best

# %%
class Solution(object):
    def largestAltitude(self, gain):
        alt = [0,gain[0]]
        for i in range(1,len(gain)):
            alt.append(alt[-1]+gain[i])
        return max(alt)
