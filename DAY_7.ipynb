# %% [markdown]
# # Find Peak Element
#
# A peak element is an element that is strictly greater than its neighbors.
#
# Given an integer array nums, find a peak element, and return its index. If the array contains multiple peaks, return the index to any of the peaks.
#
# You may imagine that nums[-1] = nums[n] = -∞.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,1]
# Output: 2
# Explanation: 3 is a peak element and your function should return the index number 2.
# Example 2:
#
# Input: nums = [1,2,1,3,5,6,4]
# Output: 5
# Explanation: Your function can return either index number 1 where the peak element is 2, or index number 5 where the peak element is 6.
#
#
# Constraints:
#
# 1 <= nums.length <= 1000
# -231 <= nums[i] <= 231 - 1
# nums[i] != nums[i + 1] for all valid i.
#
#
# Follow up: Could you implement a solution with logarithmic complexity?

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        m = max(nums)
        if len(nums)<3:
            return nums.index(m)
        for i in range(1,len(nums)):
            if nums[i-1]<nums[i] and nums[i]> nums[i+1]:
                return i
        return nums.index(m)

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        m = max(nums)
        if len(nums)<3:
            return nums.index(m)
        return nums.index(m)

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        n = len(nums)
        if n == 1:
            return 0
    
        if nums[0] > nums[1]:
            return 0
        if nums[n - 1] > nums[n - 2]:
            return n - 1

        left, right = 0, n - 1
        while left < right:
            mid = (left + right) // 2
            
            if nums[mid - 1] < nums[mid] and nums[mid + 1] < nums[mid]:
                return mid

            if nums[mid - 1] < nums[mid]:
                left = mid
            else:
                right = mid

# %%
`class Solution:
def findPeakElement(self, nums: List[int]) -> int:
if len(nums)==1:
return 0
size = len(nums)
low = 0
high = size -1
while (low <= high):
mid = low + (high -low)/2
mid = int(mid)
if mid > 0 and mid < size -1 :
if nums[mid] > nums[mid-1] and nums[mid] > nums[mid+1] :
return mid
elif nums[mid-1] > nums[mid] :
high = mid-1
else :
low = mid +1
elif mid == 0 :
if nums[mid] > nums[mid+1] :
return mid
else :
return mid+1
elif mid == size -1 :
if nums[size-1] > nums[size-2] :
return size -1
else :
return size -2

# %%
    def findPeakElement(self, nums: List[int]) -> int:
        for i in range(1,len(nums)-1):
            if nums[i]>nums[i-1] and nums[i]>nums[i+1]:
                return i
        return nums.index(max(nums))

# %%
class Solution:
    def findPeakElement(self, a: List[int]) -> int:
        if len(a)==1:
            return 0
        index=0
        for i in range(len(a)-1):
            if a[i+1]>a[i]:
                index=i+1
        return index

# %%
# fastest
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        count = 0
        if len(nums) == 1:
            return 0
        if len(nums) == 2:
            if nums[0]>nums[1]:
                return 0
            else:
                return 1

        middle  =  len(nums)//2

        if nums[middle]> nums[middle-1] and nums[middle] > nums[middle+1]:
            count += middle
        elif nums[middle] < nums[middle+1]:
            count += middle+1
            count += self.findPeakElement(nums[middle+1:])

        elif nums[middle] <nums[middle-1]:
            count = self.findPeakElement(nums[:middle])

        return count

# %% [markdown]
# # Maximum Product Subarray
#
# Given an integer array nums, find a contiguous non-empty subarray within the array that has the largest product, and return the product.
#
# It is guaranteed that the answer will fit in a 32-bit integer.
#
# A subarray is a contiguous subsequence of the array.
#
#
#
# Example 1:
#
# Input: nums = [2,3,-2,4]
# Output: 6
# Explanation: [2,3] has the largest product 6.
# Example 2:
#
# Input: nums = [-2,0,-1]
# Output: 0
# Explanation: The result cannot be 2, because [-2,-1] is not a subarray.
#
#
# Constraints:
#
# 1 <= nums.length <= 2 * 104
# -10 <= nums[i] <= 10
# The product of any prefix or suffix of nums is guaranteed to fit in a 32-bit integer.

# %%
class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        curr=0
        best=0
        for i in range(1,len(nums)):

            curr=nums[i-1]*nums[i]
            best=max(best, curr)
        return best

# %%
class Solution(object):
    def maxProduct(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if len(nums) == 0:
            return 0
        forward, backward, m = 0,0, nums[0]
        for i in range(len(nums)):
            forward = forward * nums[i] or nums[i] 
            backward =  backward * nums[len(nums) - i -1] or nums[len(nums) - i -1]
            print(max(m,forward,backward))
            m = max(m,forward,backward)
            
        return m

# %%
int maxProduct(vector<int>& arr) {
      int ans,maxp,minp;
      ans=maxp=minp=arr[0];
      for(int i=1;i<arr.size();i++){
          if(arr[i]<0) swap(maxp,minp);
          maxp =max(maxp*arr[i],arr[i]);
          minp =min(minp*arr[i],arr[i]);
          ans = max(ans,maxp);
      }
      return ans;
    }

# %%
class Solution:
    def findMaxProduct(self, l):     # l does not contain 0's
        if len(l) == 0:
            return 0
        if len(l) == 1:
            return l[0]
        
        result = 1
        for i in l:
            result *= i
        if result > 0:
            return result
        
        result_left = result
        for i in range(len(l)):
            if l[i] < 0:
                first_neg_left_idx = i
                break
        for i in l[:first_neg_left_idx+1]:
            result_left /= i
        
        result_right = result
        for i in range(len(l)-1,-1,-1):
            if l[i] < 0:
                first_neg_right_idx = i
                break
        for i in l[first_neg_right_idx:]:
            result_right /= i
            
        return max(int(result_left), int(result_right))
        
            
    
    def maxProduct(self, nums: List[int]) -> int:
        if len(nums) == 0:
            return 0
        else:
            # multiply all positive values
            processed_list = []         
            to_append = 1
            for i in range(len(nums)):
                if nums[i] <= 0:
                    if i >= 1 and nums[i-1] > 0:
                        processed_list.append(to_append)
                        to_append = 1
                    processed_list.append(nums[i])
                else:
                    to_append *= nums[i]
            if nums[-1] > 0:
                processed_list.append(to_append)
                
            # split out zeros
            start = 0
            result_list = []
            for i in range(len(processed_list)):
                if processed_list[i] == 0:
                    result_list.append(self.findMaxProduct(processed_list[start:i]))
                    result_list.append(0)
                    start = i+1
            result_list.append(self.findMaxProduct(processed_list[start:]))
        return max(result_list)

# %% [markdown]
# ### Explanation
# The idea is to loop through the input and multiply each given element with the current product if its value is not 0. We also keep track of the highest negative product such that we can divide the current product, in case it is negative, by it to obtain the highest positive product possible among all subarrays with the given element as their last one. If the given element is 0, we will reset the current and the maximum negative product.
#
# In summary, we always build the product of all non 0 elements and, if it becomes negative, we divide it by the maximum negative product. The current product is the product of all elements within a subarray which starts after the last encountered 0 or at the beginning of the input array and ranges up to the currently given element. The maximum negative product is the product of a prefix subarray which has the same starting element but covers less elements. It has the highest negative product among all prefix subarrays.
#
# Definitions
# n: The input size.
#
# Runtime Complexity
# O(n)
#
# Space Complexity
# O(1)

# %%
class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        min_product = None
        current_product = 1
        output = nums[0]
        
        for number in nums:
            output = max(output, number)
            
            if number == 0:
                current_product = 1
                min_product = None
            else:
                current_product *= number
                output = max(output, current_product)
                
                if min_product is not None:
                    other_product = current_product // min_product
                    output = max(output, other_product)
                
                if current_product < 0 and (min_product is None or current_product > min_product):
                    min_product = current_product

        return output

# %%
class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        dpmax = [None] * len(nums)
        dpmin = [None] * len(nums)
        
        ans = dpmax[0] = dpmin[0] = nums[0]
        
        for i in range(1, len(nums)):
            n = nums[i]
            
            if n >= 0:
                dpmax[i] = max(n, dpmax[i-1] * n)
                dpmin[i] = min(n, dpmin[i-1] * n)
            else:
                dpmin[i] = min(dpmax[i-1] * n, n)
                dpmax[i] = max(dpmin[i-1] * n, n)
                
            ans = max(ans, dpmax[i])
                
        return ans

# %% [markdown]
# Code is not too short. But I think it is more practical in interview.
#
# Smart code is usually tricky or merging several conditions into one long expression. However, in an interview, when I am nervous, it is likely to make mistake (maybe I am not so clever).
#
# I provide an easy to understand version of the code
#
# Define dpmax[i] as the the maximum subarray sum ending at nums[i]. So it equals to nums[k] * nums[k+1] *...* nums[i]
# Define dpmin[i] as the the minimum subarray sum ending at nums[i]. So it equals to nums[k] * nums[k+1] *...* nums[i]
#
# So let's assume we already know dpmax[i-1] and dpmin[i-1] and nums[i], how are we going to get dpmax[i] and dpmin[i]? It has something to do with the sign of nums[i]!
#
# We split into 3 conditions
#
# nums[i] > 0 => we have dpmax[i] = dpmax[i-1] * nums[i]. When get the previous greatest subarray sum multiple a positive number, we get a bigger number. But stop, imagine array [-1, 3], dpmax[1] should be 3, but dpmax[0] * nums[i] = -3. Why? Because, if we have negative numbers, some dpmax[i] must be negative inevetaly. So the correct rule is: we take whichever is bigger: nums[i] or dpmax[i] * nums[i].
# nums[i] < 0 => similar
# nums[i] = 0 => This can be merged into first condition
# Now what if an interview ask you to optimize more? You can make it constant space by rolling array

# %%
# fastest
class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        dpmax = [None] * 2
        dpmin = [None] * 2
        
        old, now = 0, 1
        
        ans = dpmax[old] = dpmin[old] = nums[0]
        
        for i in range(1, len(nums)):
            n = nums[i]
            
            if n >= 0:
                dpmax[now] = max(n, dpmax[old] * n)
                dpmin[now] = min(n, dpmin[old] * n)
            else:
                dpmin[now] = min(dpmax[old] * n, n)
                dpmax[now] = max(dpmin[old] * n, n)
                
            ans = max(ans, dpmax[now])
            
            old, now = now, old
                
        return ans

# %%
class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        # go from left (reset at 0)
        # go from right (reset at 0)
        def getMax(arr):
            product = 1
            best = -math.inf
            for n in arr:
                product *= n
                best = max(best, product)
                if product == 0:
                    product = 1
            return best
        
        return max(getMax(nums), getMax(reversed(nums)))

# %% [markdown]
# # Rotate Array
#
# Given an array, rotate the array to the right by k steps, where k is non-negative.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
# Explanation:
# rotate 1 steps to the right: [7,1,2,3,4,5,6]
# rotate 2 steps to the right: [6,7,1,2,3,4,5]
# rotate 3 steps to the right: [5,6,7,1,2,3,4]
# Example 2:
#
# Input: nums = [-1,-100,3,99], k = 2
# Output: [3,99,-1,-100]
# Explanation:
# rotate 1 steps to the right: [99,-1,-100,3]
# rotate 2 steps to the right: [3,99,-1,-100]
#
#
# Constraints:
#
# 1 <= nums.length <= 105
# -231 <= nums[i] <= 231 - 1
# 0 <= k <= 105
#
#
# Follow up:
#
# Try to come up with as many solutions as you can. There are at least three different ways to solve this problem.
# Could you do it in-place with O(1) extra space?

# %%
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        z=[]
        z.append(nums[:k+1])
        del(nums[:k+1])
        for i in z:
            nums.append(i)

# %%
k=k%len(nums)
nums[:]=nums[-k:]+nums[0:-k]

# %%
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        k = k % len(nums)
        nums[:] = nums[-k:] + nums[:-k]

# %%
def rotate(self, nums: List[int], k: int) -> None:
"""
Do not return anything, modify nums in-place instead.
"""
if (k <= len(nums)):
size= len(nums)
ans = nums[-k:] + nums[:size-k]
for i in range(len(nums)):
nums[i] = ans[i]
else:
diff = k - len(nums)
ans = nums[-diff:] + nums[:-diff]
for i in range(len(nums)):
nums[i] = ans[i]

# %%
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        n=len(nums)
        if k>n:
            k=k%n
        a=[]
        for i in range (n-k,n):
            a.append(nums[i])
        #print(a)
        s=n-k-1
        for i in range(n-1,0,-1):
            nums[i]=nums[s]
            s-=1
        m=0
        for j in range(k):
            nums[j]=a[m]
            m+=1
        if k>len(nums):
            k=k%len(nums)
    def Reverse(arr,i,n):
        while(i<n):
            arr[i],arr[n]=arr[n],arr[i]
            i+=1
            n-=1
        return arr
        nums.reverse()
        Reverse(nums,0,k-1)
        Reverse(nums,k,len(nums)-1)

# %% [markdown]
# # Minimum Size Subarray Sum
#
# Given an array of positive integers nums and a positive integer target, return the minimal length of a contiguous subarray [numsl, numsl+1, ..., numsr-1, numsr] of which the sum is greater than or equal to target. If there is no such subarray, return 0 instead.
#
#
#
# Example 1:
#
# Input: target = 7, nums = [2,3,1,2,4,3]
# Output: 2
# Explanation: The subarray [4,3] has the minimal length under the problem constraint.
# Example 2:
#
# Input: target = 4, nums = [1,4,4]
# Output: 1
# Example 3:
#
# Input: target = 11, nums = [1,1,1,1,1,1,1,1]
# Output: 0
#
#
# Constraints:
#
# 1 <= target <= 109
# 1 <= nums.length <= 105
# 1 <= nums[i] <= 105
#
#
# Follow up: If you have figured out the O(n) solution, try coding another solution of which the time complexity is O(n log(n)).
# Accepted
# 353.1K
# Submissions
# 884.5K
# Seen this question in a real interview before

# %%
class Solution:
    def minSubArrayLen(self, tar: int, nums: List[int]) -> int:
        # pre = [0 for i in range(len(nums)+1)]
        # for i in range(1, len(nums)+1):
        #     pre[i] = pre[i-1]+nums[i-1]
        
        # if pre[-1] < tar: return 0
        
        low = 0
        high = 0
        sumi = 0
        ans = len(nums)+1
        while 1:
            if sumi < tar:
                if high >= len(nums):
                    break
                sumi += nums[high]
                high += 1
            else:
                if low >= len(nums):
                    break
                ans = min(ans, high-low)
                sumi -= nums[low]
                low += 1
        if ans > len(nums):
            return 0
        return ans

# %%
import sys
class Solution:
    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        min_len=sys.maxsize
        curr_sum=0
        j=0
        for i in range(len(nums)):
            curr_sum+=nums[i]
            if curr_sum>=target:
                while curr_sum>=target:
                    min_len=min(min_len,i-j+1)
                    curr_sum-=nums[j]
                    j+=1
        if min_len==sys.maxsize:
            return -1
        return min_len

# %%
# fastest
class Solution:
    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        start=0
        end=0
        n=len(nums)
        curr_len=n+1
        curr=0
        while(end<n):

            while(curr<target and end<n):
                curr+=nums[end]
                end+=1

            while(curr>=target and start<n):
                if end-start<curr_len:
                    curr_len=end-start
                curr-=nums[start]
                start+=1

        return curr_len if curr_len!=n+1 else 0

# %%
class Solution:
    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        result= 10**9
        left=0
        s=0
        for i in range(len(nums)):
            s+=nums[i]
            while(s>=target):
                result=min(result,i+1-left)
                s-=nums[left]
                left+=1
        return result if result!=10**9 else 0
